# %%
import numpy as np

# Decision stump used as weak classifier
class DecisionStump():
    def __init__(self):
        self.polarity = 1
        self.feature_idx = None
        self.threshold = None
        self.alpha = None

# Prediction for each data stump based on threshold
    def predict_stump(self, X):
        samples = X.shape[0]
        column = X[:, self.feature_idx]
        predictions = np.ones(samples)
        if self.polarity == 1:
            predictions[column < self.threshold] = -1
        else:
            predictions[column > self.threshold] = -1

        return predictions


    
# Parameterized Adaboost for better accuracy by combining weak classifiers
class ParameterizedAdaboost():    
    
    def __init__(self, n_clf):
        self.n_clf = n_clf
        self.F=0
        self.al= 0.8
        self.err=[]
        
# Train function to train the classifier using weak classifiers
    def train(self, X, y):
        samples, features = X.shape

        # Initialize weights to 1/N
        w = np.full(samples, (1 / samples))
        self.clfs = []
        
        # Iterate through classifiers
        for _ in range(self.n_clf):
            
            clf = DecisionStump()

            min_error = float('inf')
            
            # greedy search to find best threshold and feature
            for feature_i in range(features):
                X_column = X[:, feature_i]
                thresholds = np.unique(X_column)

                for threshold in thresholds:
                    # predict with polarity 1
                    p = 1
                    predictions = np.ones(samples)
                    predictions[X_column < threshold] = -1

                    # Error = sum of weights of misclassified samples
                    misclassified = w[y != predictions]
                    error = sum(misclassified)

                    if error > 0.5:
                        error = 1 - error
                        p = -1

                    # store the best configuration
                    if error < min_error:
                        clf.polarity = p
                        clf.threshold = threshold
                        clf.feature_idx = feature_i
                        min_error = error

            # calculate ft(x)
            EPS = 1e-10
            clf.alpha = 0.5 * np.log((1.0 - min_error + EPS) / (min_error + EPS))
            
            # calulate Ft(x) from ft(x)
            self.F= self.F+ clf.alpha
                        
            # calculate predictions and update weights
            predictions = clf.predict_stump(X)
            
            z = np.sum(np.exp(-(self.F* y* predictions)-(self.al * abs(self.F*y*predictions))))

            # The weights are updated using the Ft(x) and alpha value
            w= np.exp(-(self.F* y* predictions)-(self.al * abs(self.F*y*predictions)))/z
            
            # Save classifier and append error in each weak classfier from later use
            self.clfs.append(clf)
            self.err.append(min_error)
           
        
    # prediction for test set which returns the predictions and the error on training set
    def predict(self, X):
        clf_preds = [self.F * clf.predict_stump(X) for clf in self.clfs]
        y_pred = np.sum(clf_preds, axis=0)
        y_pred = np.sign(y_pred)

        return y_pred, self.err

# %%
# CART
from random import seed
from random import randrange
from csv import reader
 
# Load a CSV file
def load_data(filename):
    file = open(filename, "rt")
    lines = reader(file)
    dataset = list(lines)
    return dataset
 
# Split a dataset into k folds
def cross_validation(dataset, n_folds):
    dataset_split = list()
    dataset_copy = list(dataset)
    fold_size = int(len(dataset) / n_folds)
    for i in range(n_folds):
        fold = list()
        while len(fold) < fold_size:
            index = randrange(len(dataset_copy))
            fold.append(dataset_copy.pop(index))
        dataset_split.append(fold)
    return dataset_split
 
# Calculate accuracy percentage
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0
 
# Evaluate an algorithm using a cross validation split
def evaluation(dataset, algorithm, n_folds, *args):
    folds = cross_validation(dataset, n_folds)
    scores = list()
    for fold in folds:
        train_set = list(folds)
        train_set.remove(fold)
        train_set = sum(train_set, [])
        test_set = list()
        for row in fold:
            row_copy = list(row)
            test_set.append(row_copy)
            row_copy[-1] = None
        predicted = algorithm(train_set, test_set, *args)
        actual = [row[-1] for row in fold]
        accuracy = accuracy_metric(actual, predicted)
        scores.append(accuracy)
    return scores
 
# Split a dataset based on an attribute and an attribute value
def train_split(index, value, dataset):
    left, right = list(), list()
    for row in dataset:
        if row[index] < value:
            left.append(row)
        else:
            right.append(row)
    return left, right
 
# Calculate the Gini index for a split dataset
def gini_index(groups, classes):
    # count all samples at split point
    n_instances = float(sum([len(group) for group in groups]))
    # sum weighted Gini index for each group
    gini = 0.0
    for group in groups:
        size = float(len(group))
        # avoid divide by zero
        if size == 0:
            continue
        score = 0.0
        # score the group based on the score for each class
        for class_val in classes:
            p = [row[-1] for row in group].count(class_val) / size
            score += p * p
        # weight the group score by its relative size
        gini += (1.0 - score) * (size / n_instances)
    return gini
 
# Select the best split point for a dataset
def get_split(dataset):
    class_values = list(set(row[-1] for row in dataset))
    b_index, b_value, b_score, b_groups = 999, 999, 999, None
    for index in range(len(dataset[0])-1):
        for row in dataset:
            groups = train_split(index, row[index], dataset)
            gini = gini_index(groups, class_values)
            if gini < b_score:
                b_index, b_value, b_score, b_groups = index, row[index], gini, groups
    return {'index':b_index, 'value':b_value, 'groups':b_groups}
 
# Create a terminal node value
def terminal(group):
    outcomes = [row[-1] for row in group]
    return max(set(outcomes), key=outcomes.count)
 
# Create child splits for a node or make terminal
def split(node, max_depth, min_size, depth):
    left, right = node['groups']
    del(node['groups'])
    # check for a no split
    if not left or not right:
        node['left'] = node['right'] = terminal(left + right)
        return
    # check for max depth
    if depth >= max_depth:
        node['left'], node['right'] = terminal(left), terminal(right)
        return
    # process left child
    if len(left) <= min_size:
        node['left'] = terminal(left)
    else:
        node['left'] = get_split(left)
        split(node['left'], max_depth, min_size, depth+1)
    # process right child
    if len(right) <= min_size:
        node['right'] = terminal(right)
    else:
        node['right'] = get_split(right)
        split(node['right'], max_depth, min_size, depth+1)
 
# Build a decision tree
def build_tree(train, max_depth, min_size):
    root = get_split(train)
    split(root, max_depth, min_size, 1)
    return root
 
# Make a prediction with a decision tree
def predict(node, row):
    if row[node['index']] < node['value']:
        if isinstance(node['left'], dict):
            return predict(node['left'], row)
        else:
            return node['left']
    else:
        if isinstance(node['right'], dict):
            return predict(node['right'], row)
        else:
            return node['right']
 
# Classification and Regression Tree Algorithm
def tree(train, test, max_depth, min_size):
    tree = build_tree(train, max_depth, min_size)
    predictions = list()
    for row in test:
        prediction = predict(tree, row)
        predictions.append(prediction)
    return(predictions)

# %%
def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

accu1=[]
accu2=[]
error=[]
name=[]

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

dataset= pd.read_csv("dataset/diabetes.csv")
name.append("Diabetes")
y= dataset["Outcome"]
dataset= dataset.drop(columns=["Outcome"])
y=y.to_numpy()
X=dataset.to_numpy()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = ParameterizedAdaboost(n_clf=5)
clf.train(X_train, y_train)
y_pred,error = clf.predict(X_test)

acc = accuracy(y_test, y_pred)
print("Error:",round(error[-1],5))
print ("Accuracy:", round(acc*100, 2), "%")
accu1.append(acc)
# Out:
# Error: 0.00195
# Accuracy: 71.43 %

# %%
n= range(1,6)
plt.plot(n,error)
plt.title('Error for datasets')
plt.xlabel('Number of weak classifiers')
plt.ylabel('Error')
plt.show()

# %%
seed(1)

filename = 'dataset/diabetes.csv'
dataset = load_data(filename)
n_folds = 2
max_depth = 1
min_size = 2

scores = evaluation(dataset, tree, n_folds, max_depth, min_size)
#print('Scores: %s' % scores)
print('Accuracy: %.2f%%' % (sum(scores)/float(len(scores))))
accu2.append(float((sum(scores)/float(len(scores)))/100))
# Out:
# Accuracy: 64.97%

# %%
import pandas as pd
dataset= pd.read_csv("dataset/heart.csv")

name.append("Heart")
y= dataset["target"]
dataset= dataset.drop(columns=["target"])
y=y.to_numpy()
X=dataset.to_numpy()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = ParameterizedAdaboost(n_clf=5)
clf.train(X_train, y_train)
y_pred,error = clf.predict(X_test)

acc = accuracy(y_test, y_pred)
print("Error:",round(error[-1],5))
print ("Accuracy:", round(acc*100, 2), "%")
accu1.append(acc)
# Out:
# Error: 0.0019
# Accuracy: 76.92 %

# %%
n= range(1,6)
plt.plot(n,error)
plt.title('Error for datasets')
plt.xlabel('Number of weak classifiers')
plt.ylabel('Error')
plt.show()

# %%
seed(1)

filename = 'dataset/heart.csv'
dataset = load_data(filename)
n_folds = 2
max_depth = 1
min_size = 2

scores = evaluation(dataset, tree, n_folds, max_depth, min_size)
#print('Scores: %s' % scores)
#print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
print('Accuracy: %.2f%%' % (sum(scores)/float(len(scores))))
accu2.append(float((sum(scores)/float(len(scores)))/100))
# Out:
# Accuracy: 66.78%

# %%
import pandas as pd
dataset= pd.read_csv("dataset/haberman.csv")
name.append("Haberman Breast Cancer")
y= dataset["Status"]
dataset= dataset.drop(columns=["Status"])
y=y.to_numpy()
X=dataset.to_numpy()
y[y==2]=-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = ParameterizedAdaboost(n_clf=5)
clf.train(X_train, y_train)
y_pred,error = clf.predict(X_test)

acc = accuracy(y_test, y_pred)
print("Error:",round(error[-1],5))
print ("Accuracy:", round(acc*100, 2), "%")
accu1.append(acc)
# Out:
# Error: 0.00965
# Accuracy: 73.91 %

# %%
n= range(1,6)
plt.plot(n,error)
plt.title('Error for datasets')
plt.xlabel('Number of weak classifiers')
plt.ylabel('Error')
plt.show()

# %%
seed(1)

filename = 'dataset/haberman.csv'
dataset = load_data(filename)
n_folds = 2
max_depth = 1
min_size = 2

scores = evaluation(dataset, tree, n_folds, max_depth, min_size)
#print('Scores: %s' % scores)
#print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
print('Accuracy: %.2f%%' % (sum(scores)/float(len(scores))))
accu2.append(float((sum(scores)/float(len(scores)))/100))
# Out:
# Accuracy: 73.20%

# %%
import pandas as pd
dataset= pd.read_csv("dataset/framingham.csv")
name.append("Framingham Heart Study")
dataset= dataset.dropna()
y= dataset["TenYearCHD"]
dataset= dataset.drop(columns=["TenYearCHD"])
y=y.to_numpy()
X=dataset.to_numpy()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = ParameterizedAdaboost(n_clf=5)
clf.train(X_train, y_train)
y_pred,error = clf.predict(X_test)

acc = accuracy(y_test, y_pred)
print("Error:",round(error[-1],5))
print ("Accuracy:", round(acc*100, 2), "%")
accu1.append(acc)
# Out:
# Error: 0.00018
# Accuracy: 85.06 %

# %%
n= range(1,6)
plt.plot(n,error)
plt.title('Error for datasets')
plt.xlabel('Number of weak classifiers')
plt.ylabel('Error')
plt.show()

# %%
seed(1)

filename = 'dataset/framingham.csv'
dataset = load_data(filename)
n_folds = 2
max_depth = 1
min_size = 2

scores = evaluation(dataset, tree, n_folds, max_depth, min_size)
#print('Scores: %s' % scores)
print('Accuracy: %.2f%%' % (sum(scores)/float(len(scores))))
accu2.append(float((sum(scores)/float(len(scores)))/100))
# Out:
# Accuracy: 84.81%

# %%
import pandas as pd
dataset= pd.read_csv("dataset/heart_cleveland_upload.csv")
name.append("Cleaveland Heart Study")
y= dataset["condition"]
dataset= dataset.drop(columns=["condition"])
y=y.to_numpy()
X=dataset.to_numpy()
y[y==0]=-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = ParameterizedAdaboost(n_clf=5)
clf.train(X_train, y_train)
y_pred,error = clf.predict(X_test)

acc = accuracy(y_test, y_pred)
print("Error:",round(error[-1],5))
print ("Accuracy:", round(acc*100, 2), "%")
accu1.append(acc)
# Out:
# Error: 0.00224
# Accuracy: 77.78 %

# %%
n= range(1,6)
plt.plot(n,error)
plt.title('Error for datasets')
plt.xlabel('Number of weak classifiers')
plt.ylabel('Error')
plt.show()

# %%
seed(1)

filename = 'dataset/heart_cleveland_upload.csv'
dataset = load_data(filename)
n_folds = 2
max_depth = 1
min_size = 2

scores = evaluation(dataset, tree, n_folds, max_depth, min_size)
print('Accuracy: %.2f%%' % (sum(scores)/float(len(scores))))
accu2.append(float((sum(scores)/float(len(scores)))/100))
# Out:
# Accuracy: 74.50%

# %%
# The bar graph which gives the Accuracy against the different datasets for Parameterized Adaboost and Decision Tree


x = np.arange(5) # the graph is set to be subdivided into 5 groups
width = 0.15
fig, axis = plt.subplots(figsize=(15,15))
rects1 = axis.bar(x - 0.225, accu1, width, label='Parameterised Adaboost') # each bar is set to represent evaluation method
rects2 = axis.bar(x- 0.075, accu2, width, label='Decision Tree')

# The labels and the axis and set using subplot methods
axis.set_xlabel('Datasets', size=20)
axis.set_ylabel('Accuracy', size=20)
axis.set_title('Accuracy for datasets (Parameterised Adaboost and Decision Tree)', size=15)
axis.set_xticks(x)
axis.set_xticklabels(name)
axis.legend()

# function to link the data with the labels
def bar(rects):
    for rect in rects:
        height = rect.get_height()
        
bar(rects1)
bar(rects2)

fig.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,5)) # set figure size
plt.plot(name, accu1, 'g', label='Parameterized Adaboost') #Subplot 1
plt.plot(name, accu2, 'b', label='Decision Tree with depth 1') # Subplot 2
# Details on the graph is provided
plt.title('Accuracy for datasets')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
